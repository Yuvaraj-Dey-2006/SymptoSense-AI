# %%
import json
import pandas as pd

# %%
# Load the JSON dataset
with open("Original Datasets/intents.json", "r") as file:
    data = json.load(file)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
rows = []

for intent in data["intents"]:
    tag = intent["tag"]

    for pattern in intent["patterns"]:
        rows.append({
            "tag": tag,
            "pattern": pattern,
            "response": intent["responses"][0]
        })

df = pd.DataFrame(rows)

df.head()
# Out:
#               tag          pattern  \
# 0        greeting               Hi
# 1        greeting            Hello
# 2        greeting              Hey
# 3        greeting        Greetings
# 4  cancer_general  What is cancer?
#
#                                             response
# 0  Hello! How can I assist you with Medical Assis...
# 1  Hello! How can I assist you with Medical Assis...
# 2  Hello! How can I assist you with Medical Assis...
# 3  Hello! How can I assist you with Medical Assis...
# 4  Cancer is a group of diseases characterized by...

# %%
print("Final Dataset Shape:")
print(df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nData Information:")
df.info()
# Out:
# Final Dataset Shape:
# (98, 3)
#
# Columns:
# ['tag', 'pattern', 'response']
#
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tag       98 non-null     object
#  1   pattern   98 non-null     object
#  2   response  98 non-null     object
# dtypes: object(3)
# memory usage: 2.4+ KB

# %%
print("Missing Values:")
display(df.isnull().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Missing Values:
# tag         0
# pattern     0
# response    0
# dtype: int64
# Duplicate Rows:
# 0

# %%
# Number of words in each user query
df["pattern_length"] = df["pattern"].apply(lambda x: len(x.split()))

# Number of words in chatbot response
df["response_length"] = df["response"].apply(lambda x: len(x.split()))

df.head()
# Out:
#               tag          pattern  \
# 0        greeting               Hi
# 1        greeting            Hello
# 2        greeting              Hey
# 3        greeting        Greetings
# 4  cancer_general  What is cancer?
#
#                                             response  pattern_length  \
# 0  Hello! How can I assist you with Medical Assis...               1
# 1  Hello! How can I assist you with Medical Assis...               1
# 2  Hello! How can I assist you with Medical Assis...               1
# 3  Hello! How can I assist you with Medical Assis...               1
# 4  Cancer is a group of diseases characterized by...               3
#
#    response_length
# 0               10
# 1               10
# 2               10
# 3               10
# 4               40

# %%
df.describe(include="all")
# Out:
#                         tag pattern  \
# count                    98      98
# unique                   22      98
# top     alzheimers_symptoms      Hi
# freq                      5       1
# mean                    NaN     NaN
# std                     NaN     NaN
# min                     NaN     NaN
# 25%                     NaN     NaN
# 50%                     NaN     NaN
# 75%                     NaN     NaN
# max                     NaN     NaN
#
#                                                  response  pattern_length  \
# count                                                  98       98.000000
# unique                                                 22             NaN
# top     It seems like you may be experiencing symptoms...             NaN
# freq                                                    5             NaN
# mean                                                  NaN        8.122449
# std                                                   NaN        6.498636
# min                                                   NaN        1.000000
# 25%                                                   NaN        4.000000
# 50%                                                   NaN        6.000000
# 75%                                                   NaN       10.000000
# max                                                   NaN       29.000000
#
#         response_length
# count         98.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean          43.561224
# std           24.176783
# min           10.000000
# 25%           25.750000
# 50%           35.000000
# 75%           67.750000
# max           87.000000

# %%
df.to_csv("Processed Datasets/processed_data.csv", index=False)

columns = pd.DataFrame(df.columns, columns=["Column_Name"])
columns.to_csv(
    "Processed Datasets/processed_data_columns.csv",
    index=False
)

print("Processed files saved successfully!")
# Out:
# Processed files saved successfully!

# %%
processed_df = pd.read_csv("Processed Datasets/processed_data.csv")
processed_df.head()
# Out:
#               tag          pattern  \
# 0        greeting               Hi
# 1        greeting            Hello
# 2        greeting              Hey
# 3        greeting        Greetings
# 4  cancer_general  What is cancer?
#
#                                             response  pattern_length  \
# 0  Hello! How can I assist you with Medical Assis...               1
# 1  Hello! How can I assist you with Medical Assis...               1
# 2  Hello! How can I assist you with Medical Assis...               1
# 3  Hello! How can I assist you with Medical Assis...               1
# 4  Cancer is a group of diseases characterized by...               3
#
#    response_length
# 0               10
# 1               10
# 2               10
# 3               10
# 4               40
